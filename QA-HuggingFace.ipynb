# %% [markdown]
# ### HuggingFace
#
# In questa parte esploreremo un'altra libreria per poter fare esattamente tutto quello che abbiamo imparato prima, in modo più immediato.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
import torch
import json
from tqdm import tqdm
import numpy as np
from pprint import pprint

# %%
model_name = "deepset/roberta-base-squad2" # "mrm8488/longformer-base-4096-finetuned-squadv2"

# a) Get predictions
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)

# %%
QA_input = {
    'question': 'Why is model conversion important?',
    'context': 'The option to convert models between FARM and transformers gives freedom to the user and let people easily switch between frameworks.'
}
res = nlp(QA_input)

print(res)
# Out:
# {'score': 0.21171511709690094, 'start': 59, 'end': 84, 'answer': 'gives freedom to the user'}

# %%
# b) Load model & tokenizer
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
text = r"""
🤗 Transformers (formerly known as pytorch-transformers and pytorch-pretrained-bert) provides general-purpose
architectures (BERT, GPT-2, RoBERTa, XLM, DistilBert, XLNet…) for Natural Language Understanding (NLU) and Natural
Language Generation (NLG) with over 32+ pretrained models in 100+ languages and deep interoperability between
TensorFlow 2.0 and PyTorch.
"""

questions = [
    "How many pretrained models are available in Transformers?",
    "What does Transformers provide?",
    "Transformers provides interoperability between which frameworks?",
]

for question in questions:
    inputs = tokenizer.encode_plus(question, text, add_special_tokens=True, return_tensors="pt")
    input_ids = inputs["input_ids"].tolist()[0]

    text_tokens = tokenizer.convert_ids_to_tokens(input_ids)
    model_output = model(**inputs)
    answer_start_scores = model_output["start_logits"]
    answer_end_scores = model_output["end_logits"]

    answer_start = torch.argmax(
        answer_start_scores
    )  # Get the most likely beginning of answer with the argmax of the score
    answer_end = torch.argmax(answer_end_scores) + 1  # Get the most likely end of answer with the argmax of the score

    answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(input_ids[answer_start:answer_end]))

    print(f"Question: {question}")
    print(f"Answer: {answer}\n")
# Out:
# Question: How many pretrained models are available in Transformers?
# Answer:  32+
#
# Question: What does Transformers provide?
# Answer:  general-purpose
# architectures
#
# Question: Transformers provides interoperability between which frameworks?
# Answer: <s>

# %%
for question in questions:
    QA_input = {
        'question': question,
        'context': text
    }
    answer = nlp(QA_input)["answer"]

    print(f"Question: {question}")
    print(f"Answer: {answer}\n")
# Out:
# Question: How many pretrained models are available in Transformers?
# Answer: 32+
#
# Question: What does Transformers provide?
# Answer: general-purpose
# architectures
#
# Question: Transformers provides interoperability between which frameworks?
# Answer:
# TensorFlow 2.0 and PyTorch

# %% [markdown]
# ### Testiamolo sul DEV set di SQUAD v2
#
# In questa parte andiamo a verificare le performance di questo modello su SQUAD v2 Dev set

# %%
squad_dev = json.load(open("./SQUAD/dev-v2.0.json"))

# %%
qa_collection = []

for passage in squad_dev["data"]:
    for paragraph in passage["paragraphs"]:
        text = paragraph["context"]
        for qas in paragraph["qas"]:
            question = qas["question"]
            for answer_info in qas["answers"]:
                answer = answer_info["text"]
                qa_collection.append({
                    "text": text,
                    "question": question,
                    "answer": answer,
                })

# %%
np.random.shuffle(qa_collection)
for i,sample in enumerate(tqdm(qa_collection[:100])):
    QA_input = {
        'question': sample["question"],
        'context': sample["text"]
    }
    predicted_answer = nlp(QA_input)
    qa_collection[i]["roberta_answer"] = predicted_answer
# Out:
# 100%|██████████| 100/100 [01:14<00:00,  1.34it/s]

# %%
exact_match = 0
soft_match = 0
wrong_prediction = []

for sample in qa_collection[:100]:
    question = sample['question']
    answer = sample['answer']
    if 'roberta_answer' in sample:
        roberta_answer = sample['roberta_answer']['answer']
    else:
        roberta_answer = "None"
        
    print("*********************")
    print(f"Question: {question}")
    print(f"Answer: {answer}")
    print(f"Roberta Answer: {roberta_answer}")
    
    if answer == roberta_answer:
        exact_match += 1
    if roberta_answer in answer or answer in roberta_answer:
        soft_match += 1
    else:
        wrong_prediction.append(sample)
# Out:
# *********************
# Question: The Rhine forms an inland delta into which lake?
# Answer: Lake Constance
# Roberta Answer: Lake Constance
# *********************
# Question: How long is one term for an elected president of the CJEU?
# Answer: three years
# Roberta Answer: three years
# *********************
# Question: A formal design team may be assembled to do what?
# Answer: plan the physical proceedings, and to integrate those proceedings with the other parts
# Roberta Answer: plan the physical proceedings
# *********************
# Question: Stable and radioactive isotope studies provide insight into what?
# Answer: geochemical evolution of rock units
# Roberta Answer: geochemical evolution of rock units
# *********************
# Question: How can you find the absolute age of sedimentary rock units which do not contain radioactive isotopes?
# Answer: Dating of lava and volcanic ash layers found within a stratigraphic sequence
# Roberta Answer: Dating of lava and volcanic ash layers found within a stratigraphic sequence
# *********************
# Question: Why were Northern Chinese ranked higher?
# Answer: The earlier they surrendered to the Mongols
# Roberta Answer: The earlier they surrendered to the Mongols
# *********************
# Question: How much of Paris' population was killed by the plague?
# Answer: 100,000
# Roberta Answer: Half
# *********************
# Question: Which reason is given sometimes to plead not guilty involving these matters?
# Answer: Guilt implies wrong-doing
# Roberta Answer: Guilt implies wrong-doing
# *********************
# Question: What is the ranking of the military forces in Jacksonville?
# Answer: third largest military presence
# Roberta Answer: third largest
# *********************
# Question: On what day does a General Question Time take place?
# Answer: Thursday
# Roberta Answer: Thursday
# *********************
# Question: The symbol for mercuric oxide is?
# Answer: HgO
# Roberta Answer: HgO
# *********************
# Question: Brownlee argues that sometimes people behave in what way to have their issue heard?
# Answer: employ limited coercion
# Roberta Answer: limited coercion
# *********************
# Question: Rather than the fuel, what is oxygen to a fire?
# Answer: oxidant
# Roberta Answer: oxidant
# *********************
# Question: Southern California's economy can be described as one of the largest in the United States and what other characteristic?
# Answer: diverse
# Roberta Answer: diverse
# *********************
# Question: What act sets the term for judging the boundaries of sanity to which individuals wishing to sit on the SP must adhere?
# Answer: Mental Health (Care and Treatment) (Scotland) Act 2003
# Roberta Answer: Mental Health (Care and Treatment) (Scotland) Act 2003
# *********************
# Question: In a type III secretion system, proteins are transported to the host cell in order to do what?
# Answer: shut down host defenses
# Roberta Answer: shut down host defenses
# *********************
# Question: When was the scale to measure the Rhine introduced?
# Answer: 1939
# Roberta Answer: 1939
# *********************
# Question: How much damage does breathing oxygen in space conditions cause?
# Answer: no damage
# Roberta Answer: no damage
# *********************
# Question: How much turbine power is consumed by the pump while the work fluid is condensed?
# Answer: 1% to 3%
# Roberta Answer: 1% to 3%
# *********************
# Question: When did the Germanic tribes claim territory in north and west Europe?
# Answer: middle period of classical antiquity
# Roberta Answer: middle period of classical antiquity
# *********************
# Question: Which park is home to the Fresno Chafffee Zoo?
# Answer: Roeding Park
# Roberta Answer: Roeding Park
# *********************
# Question: How is the process of allocating seats repeated until all available seats have been determined?
# Answer: iteratively
# Roberta Answer: iteratively
# *********************
# Question: What kind of disorders are the result of an overactive immune response?
# Answer: autoimmune
# Roberta Answer: autoimmune disorders
# *********************
# Question: What researcher first used the word oxygen ?
# Answer: Antoine Lavoisier
# Roberta Answer: Antoine Lavoisier
# *********************
# Question: Which entity developed the principles of European Union Law?
# Answer: the European Court
# Roberta Answer: European Court of Justice
# *********************
# Question: In what year was a set of significant rule changes introduced including the forward pass?
# Answer: 1906
# Roberta Answer: 1906
# *********************
# Question: Most imperialism was carried out using which method of transport?
# Answer: sea and trade routes
# Roberta Answer: sea
# *********************
# Question: What type of ballot is used to elect the Presiding Officer and deputies of the Parliament?
# Answer: secret
# Roberta Answer: secret ballot
# *********************
# Question: On an international level, which industry's competitive positions is affected?
# Answer: automobiles
# Roberta Answer: automobiles
# *********************
# Question: What military impact did Huguenot immigration have on Frederick's army?
# Answer: furnished two new regiments of his army
# Roberta Answer: two new regiments
# *********************
# Question: What characteristic of oxygen makes it necessary to life?
# Answer: energy content
# Roberta Answer: energy content
# *********************
# Question: When did the Shah kingdom start to collapse?
# Answer: January 1979
# Roberta Answer: January 1979
# *********************
# Question: What year did the the case go before the supreme court?
# Answer: 1978
# Roberta Answer: 1978
# *********************
# Question: What was the result of the disobedience protesting the nuclear site?
# Answer: one at a time they stepped across the "line" and were immediately arrested
# Roberta Answer: suspended sentences
# *********************
# Question: What city north of New York was settled by Huguenots?
# Answer: New Rochelle
# Roberta Answer: New Rochelle
# *********************
# Question: What was the accepted length of the Rhine prior to 1932?
# Answer: 1,230 kilometres (764 miles)
# Roberta Answer: 1,230 kilometres
# *********************
# Question: What career does Joseph Stiglitz have?
# Answer: Economist
# Roberta Answer: Economist
# *********************
# Question: When was Zhu Shijie born?
# Answer: 1249
# Roberta Answer: 1249
# *********************
# Question: The Rhine first formed a boundary between Gaul and what else?
# Answer: Germania
# Roberta Answer: Germania
# *********************
# Question: What are sometimes present in the boiler's firebox crown?
# Answer: Lead fusible plugs
# Roberta Answer: Lead fusible plugs
# *********************
# Question: What is the name of the donor who helped establish the Hutchinson Commons?
# Answer: Charles L. Hutchinson
# Roberta Answer: Charles L. Hutchinson
# *********************
# Question: What was normal British defense?
# Answer: local militia companies
# Roberta Answer: Most British colonies mustered local militia companies
# *********************
# Question: Cells of the site of an infection in a plant undergo what process to prevent spread of the disease?
# Answer: apoptosis
# Roberta Answer: rapid apoptosis
# *********************
# Question: What is consultant pharmacy mainly concerned with?
# Answer: medication regimen review
# Roberta Answer: medication regimen review
# *********************
# Question: What prompted Shen Kuo to believe the land was formed by erosion of the mountains?
# Answer: fossil animal shells
# Roberta Answer: fossil animal shells
# *********************
# Question: Why are researchers struggling to identify the history of the plague?
# Answer: the lack of reliable statistics from this period
# Roberta Answer: lack of reliable statistics
# *********************
# Question: What vote on a bill takes place in Stage 3?
# Answer: final
# Roberta Answer: final
# *********************
# Question: Large public works, dams, bridges, highways, water/wastewater and utility distribution are under what construction sector?
# Answer: Infrastructure
# Roberta Answer: Infrastructure
# *********************
# Question: How much of Afghanistan did the Taliban take over?
# Answer: roughly 80%
# Roberta Answer: 80%
# *********************
# Question: What does Kuznets' curve predict about income inequality given time?
# Answer: decrease
# Roberta Answer: decrease
# *********************
# Question: What are three kinds of phagocytes?
# Answer: macrophages, neutrophils, and dendritic cells
# Roberta Answer: macrophages, neutrophils, and dendritic cells
# *********************
# Question: Which court argued that the Treaty of Rome did not prevent energy nationalism?
# Answer: The Italian Constitutional Court
# Roberta Answer: the Court of Justice
# *********************
# Question: How many drugs approved by the FDA in 2013 were specialty drugs?
# Answer: 19
# Roberta Answer: 19
# *********************
# Question: Who is the Costa Rican President that went to Harvard?
# Answer: José María Figueres
# Roberta Answer: José María Figueres
# *********************
# Question: What are the Sky Q mini set top boxes able to connect to?
# Answer: Sky Q Silver set top boxes
# Roberta Answer: Sky Q Silver set top boxes
# *********************
# Question: Along with the Congregation of Christian Brothers, what is a notable religious group that runs fee-paying schools in Ireland?
# Answer: the Society of Jesus
# Roberta Answer: Society of Jesus
# *********************
# Question: Who did the Normans team up with in Anatolia?
# Answer: Turkish forces
# Roberta Answer: Turkish
# *********************
# Question: What London neighborhood attracted Huguenot refugees?
# Answer: Shoreditch
# Roberta Answer: Shoreditch
# *********************
# Question: What does the Riemann hypothesis state the source of irregularity in the distribution of points comes from?
# Answer: random noise
# Roberta Answer: random noise
# *********************
# Question: Where in Central Asia did the Han Chinese move?
# Answer: Besh Baliq, Almaliq, and Samarqand
# Roberta Answer: Besh Baliq, Almaliq, and Samarqand
# *********************
# Question: What was the percentage of Black or African-Americans living in the city?
# Answer: 8.4%
# Roberta Answer: 8.4%
# *********************
# Question: What is a typical configuration
# Answer: run IP over ATM or a version of MPLS
# Roberta Answer: to run IP over ATM or a version of MPLS
# *********************
# Question: When were the Mongols defeated by the Tran?
# Answer: 1288
# Roberta Answer: 1288
# *********************
# Question: What theorem was implicated by Manuel Blum's axioms?
# Answer: speed-up theorem
# Roberta Answer: speed-up theorem
# *********************
# Question: In what conditions were forces first measured historically?
# Answer: conditions of static equilibrium
# Roberta Answer: static equilibrium
# *********************
# Question: Who refused to act until Loudoun approved plans?
# Answer: Abercrombie
# Roberta Answer: Abercrombie
# *********************
# Question: What was causing New France to have issues with resupplying?
# Answer: British blockade of the French coastline
# Roberta Answer: British blockade of the French coastline
# *********************
# Question: What describes the proportionality of acceleration to force and mass?
# Answer: Newton's Second Law
# Roberta Answer: Newton's Second Law
# *********************
# Question: What does child well-being in rich countries correlate most to?
# Answer: greater equality
# Roberta Answer: greater equality
# *********************
# Question: Who took command of French in spring of 1753?
# Answer: Paul Marin de la Malgue
# Roberta Answer: Paul Marin de la Malgue
# *********************
# Question: What was the occupation of Joseph Priestley?
# Answer: clergyman
# Roberta Answer: clergyman
# *********************
# Question: How far from Warsaw does the Vistula river's environment change noticeably?
# Answer: 15 kilometres
# Roberta Answer: 15 kilometres
# *********************
# Question: How are the particle forces and accelerations explained as by gauge bosons exchange?
# Answer: mathematical by-product of exchange
# Roberta Answer: mathematical
# *********************
# Question: Immunological memory can take what two forms?
# Answer: passive short-term memory or active long-term memory
# Roberta Answer: passive short-term memory or active long-term memory
# *********************
# Question: Huguenots in Killeshandra and County Cavan expanded what agricultural industry?
# Answer: flax cultivation
# Roberta Answer: flax cultivation
# *********************
# Question: How recently has the homes in Fresno been restored?
# Answer: recent decades
# Roberta Answer: recent decades
# *********************
# Question: Who owns more wealth than the bottom 90 percent of people in the U.S.?
# Answer: richest 1 percent
# Roberta Answer: richest 1 percent
# *********************
# Question: Why do polar water bodies support a higher amount of life?
# Answer: due to their higher oxygen content
# Roberta Answer: higher oxygen content
# *********************
# Question: What scientific field's theory has received contributions from the steam engine?
# Answer: thermodynamic theory
# Roberta Answer: thermodynamic
# *********************
# Question: What is an example of an article of uniform clothing typically present in Australian private schools?
# Answer: blazer
# Roberta Answer: compulsory blazer
# *********************
# Question: What did the Taliban want to subject the entire country to?
# Answer: an idealized and systematized version of conservative tribal village customs
# Roberta Answer: Sharia
# *********************
# Question: What type of regime ruled over Sudan for many years?
# Answer: Islamist
# Roberta Answer: Islamist
# *********************
# Question: What did Artur Oppman give to the world?
# Answer: The best-known legend
# Roberta Answer: mermaid.
# *********************
# Question: How frequent is snow in the Southwest of the state?
# Answer: very rare
# Roberta Answer: very rare
# *********************
# Question: Whose principles were the principle of faunal succession built upon?
# Answer: William Smith
# Roberta Answer: William Smith
# *********************
# Question: What percentage of seats did political parties identifying as Islamist win in the Egyptian parliamentary election of 2011-2012?
# Answer: 75% of the total seats
# Roberta Answer: 75%
# *********************
# Question: By which year did Chrysler ended its full sized luxury model?
# Answer: 1981
# Roberta Answer: 1981
# *********************
# Question: In U.S. states, what happens to the life expectancy in less economically equal ones?
# Answer: lower
# Roberta Answer: lower
# *********************
# Question: What other clashes were involved in taking Louisbourg?
# Answer: Petitcodiac in 1755 and at Bloody Creek near Annapolis Royal in 1757
# Roberta Answer: Petitcodiac in 1755 and at Bloody Creek
# *********************
# Question: By justification certain racial and geographical theories, Europe thought of itself as what?
# Answer: superior
# Roberta Answer: the superior and the norm
# *********************
# Question: In what part of the 19th century were steam turbines introduced?
# Answer: late part
# Roberta Answer: late
# *********************
# Question: The region was a leader in what event between 2001 - 2007?
# Answer: the housing bubble
# Roberta Answer: housing bubble
# *********************
# Question: How many tree species are in the rainforest?
# Answer: 1,100
# Roberta Answer: 1,100
# *********************
# Question: Highways built in the Amazon rainforest were built primarily for what kind of farmers?
# Answer: soy
# Roberta Answer: soy
# *********************
# Question: The adaptive immune system recognizes non-self antigens during a process called what?
# Answer: antigen presentation
# Roberta Answer: antigen presentation
# *********************
# Question: What religion's schools were integrated into New Zealand public schools between 1979 and 1984?
# Answer: Catholic
# Roberta Answer: Catholic
# *********************
# Question: What character in the play portrays civil disobedience?
# Answer: Antigone
# Roberta Answer: Antigone
# *********************
# Question: When was the Polish-Bolshevik war fought?
# Answer: 1920
# Roberta Answer: 1920
# *********************
# Question: Who invented a high-pressure steam engine around 1800?
# Answer: Richard Trevithick
# Roberta Answer: Richard Trevithick
# *********************
# Question: Which group benefited from the funds distributed by the religious charity, al-Haramain Foundation?
# Answer: Al-Qaeda and the Taliban
# Roberta Answer: Al-Qaeda and the Taliban

# %%
print(f"Exact Match accuracy: {exact_match / 100}")
print(f"Soft Match accuracy: {soft_match / 100}")
# Out:
# Exact Match accuracy: 0.69
# Soft Match accuracy: 0.94

# %%
for wrng in wrong_prediction:
    pprint(wrng)
# Out:
# {'answer': '100,000',
#  'question': "How much of Paris' population was killed by the plague?",
#  'roberta_answer': {'answer': 'Half',
#                     'end': 203,
#                     'score': 0.9059361219406128,
#                     'start': 199},
#  'text': 'The most widely accepted estimate for the Middle East, including '
#          'Iraq, Iran and Syria, during this time, is for a death rate of about '
#          "a third. The Black Death killed about 40% of Egypt's population. "
#          "Half of Paris's population of 100,000 people died. In Italy, the "
#          'population of Florence was reduced from 110–120 thousand inhabitants '
#          'in 1338 down to 50 thousand in 1351. At least 60% of the population '
#          'of Hamburg and Bremen perished, and a similar percentage of '
#          'Londoners may have died from the disease as well. Interestingly '
#          'while contemporary reports account of mass burial pits being created '
#          'in response to the large numbers of dead, recent scientific '
#          'investigations of a burial pit in Central London found '
#          'well-preserved individuals to be buried in isolated, evenly spaced '
#          'graves, suggesting at least some pre-planning and Christian burials '
#          'at this time. Before 1350, there were about 170,000 settlements in '
#          'Germany, and this was reduced by nearly 40,000 by 1450. In 1348, the '
#          'plague spread so rapidly that before any physicians or government '
#          'authorities had time to reflect upon its origins, about a third of '
#          'the European population had already perished. In crowded cities, it '
#          'was not uncommon for as much as 50% of the population to die. The '
#          'disease bypassed some areas, and the most isolated areas were less '
#          'vulnerable to contagion. Monks and priests were especially hard hit '
#          'since they cared for victims of the Black Death.'}
# {'answer': 'the European Court',
#  'question': 'Which entity developed the principles of European Union Law?',
#  'roberta_answer': {'answer': 'European Court of Justice',
#                     'end': 112,
#                     'score': 0.5029648542404175,
#                     'start': 87},
#  'text': 'The principles of European Union law are rules of law which have '
#          'been developed by the European Court of Justice that constitute '
#          'unwritten rules which are not expressly provided for in the treaties '
#          'but which affect how European Union law is interpreted and applies. '
#          'In formulating these principles, the courts have drawn on a variety '
#          'of sources, including: public international law and legal doctrines '
#          'and principles present in the legal systems of European Union member '
#          'states and in the jurisprudence of the European Court of Human '
#          'Rights. Accepted general principles of European Union Law include '
#          'fundamental rights (see human rights), proportionality, legal '
#          'certainty, equality before the law and subsidiarity.'}
# {'answer': 'one at a time they stepped across the "line" and were immediately '
#            'arrested',
#  'question': 'What was the result of the disobedience protesting the nuclear '
#              'site?',
#  'roberta_answer': {'answer': 'suspended sentences',
#                     'end': 778,
#                     'score': 0.10580659657716751,
#                     'start': 759},
#  'text': 'When the Committee for Non-Violent Action sponsored a protest in '
#          'August 1957, at the Camp Mercury nuclear test site near Las Vegas, '
#          'Nevada, 13 of the protesters attempted to enter the test site '
#          'knowing that they faced arrest. At a pre-arranged announced time, '
#          'one at a time they stepped across the "line" and were immediately '
#          'arrested. They were put on a bus and taken to the Nye County seat of '
#          'Tonopah, Nevada, and arraigned for trial before the local Justice of '
#          'the Peace, that afternoon. A well known civil rights attorney, '
#          'Francis Heisler, had volunteered to defend the arrested persons, '
#          'advising them to plead "nolo contendere", as an alternative to '
#          'pleading either guilty or not-guilty. The arrested persons were '
#          'found "guilty," nevertheless, and given suspended sentences, '
#          'conditional on their not reentering the test site grounds.[citation '
#          'needed]'}
# {'answer': 'The Italian Constitutional Court',
#  'question': 'Which court argued that the Treaty of Rome did not prevent '
#              'energy nationalism?',
#  'roberta_answer': {'answer': 'the Court of Justice',
#                     'end': 1063,
#                     'score': 0.4558366537094116,
#                     'start': 1043},
#  'text': 'Since its founding, the EU has operated among an increasing '
#          'plurality of national and globalising legal systems. This has meant '
#          'both the European Court of Justice and the highest national courts '
#          'have had to develop principles to resolve conflicts of laws between '
#          "different systems. Within the EU itself, the Court of Justice's view "
#          'is that if EU law conflicts with a provision of national law, then '
#          'EU law has primacy. In the first major case in 1964, Costa v ENEL, a '
#          'Milanese lawyer, and former shareholder of an energy company, named '
#          'Mr Costa refused to pay his electricity bill to Enel, as a protest '
#          'against the nationalisation of the Italian energy corporations. He '
#          'claimed the Italian nationalisation law conflicted with the Treaty '
#          'of Rome, and requested a reference be made to both the Italian '
#          'Constitutional Court and the Court of Justice under TFEU article '
#          '267. The Italian Constitutional Court gave an opinion that because '
#          'the nationalisation law was from 1962, and the treaty was in force '
#          'from 1958, Costa had no claim. By contrast, the Court of Justice '
#          'held that ultimately the Treaty of Rome in no way prevented energy '
#          'nationalisation, and in any case under the Treaty provisions only '
#          'the Commission could have brought a claim, not Mr Costa. However, in '
#          'principle, Mr Costa was entitled to plead that the Treaty conflicted '
#          'with national law, and the court would have a duty to consider his '
#          'claim to make a reference if there would be no appeal against its '
#          'decision. The Court of Justice, repeating its view in Van Gend en '
#          'Loos, said member states "albeit within limited spheres, have '
#          'restricted their sovereign rights and created a body of law '
#          'applicable both to their nationals and to themselves" on the "basis '
#          'of reciprocity". EU law would not "be overridden by domestic legal '
#          'provisions, however framed... without the legal basis of the '
#          'community itself being called into question." This meant any '
#          '"subsequent unilateral act" of the member state inapplicable. '
#          'Similarly, in Amministrazione delle Finanze v Simmenthal SpA, a '
#          'company, Simmenthal SpA, claimed that a public health inspection fee '
#          'under an Italian law of 1970 for importing beef from France to Italy '
#          'was contrary to two Regulations from 1964 and 1968. In "accordance '
#          'with the principle of the precedence of Community law," said the '
#          'Court of Justice, the "directly applicable measures of the '
#          'institutions" (such as the Regulations in the case) "render '
#          'automatically inapplicable any conflicting provision of current '
#          'national law". This was necessary to prevent a "corresponding '
#          'denial" of Treaty "obligations undertaken unconditionally and '
#          'irrevocably by member states", that could "imperil the very '
#          'foundations of the" EU. But despite the views of the Court of '
#          'Justice, the national courts of member states have not accepted the '
#          'same analysis.'}
# {'answer': 'an idealized and systematized version of conservative tribal '
#            'village customs',
#  'question': 'What did the Taliban want to subject the entire country to?',
#  'roberta_answer': {'answer': 'Sharia',
#                     'end': 482,
#                     'score': 0.5128074288368225,
#                     'start': 476},
#  'text': 'The Taliban were spawned by the thousands of madrasahs the Deobandi '
#          'movement established for impoverished Afghan refugees and supported '
#          'by governmental and religious groups in neighboring Pakistan. The '
#          'Taliban differed from other Islamist movements to the point where '
#          'they might be more properly described as Islamic fundamentalist or '
#          'neofundamentalist, interested in spreading "an idealized and '
#          'systematized version of conservative tribal village customs" under '
#          'the label of Sharia to an entire country. Their ideology was also '
#          'described as being influenced by Wahhabism, and the extremist '
#          'jihadism of their guest Osama bin Laden.'}
# {'answer': 'The best-known legend',
#  'question': 'What did Artur Oppman give to the world?',
#  'roberta_answer': {'answer': 'mermaid.',
#                     'end': 641,
#                     'score': 1.8117296463060484e-07,
#                     'start': 633},
#  'text': 'The origin of the legendary figure is not fully known. The '
#          "best-known legend, by Artur Oppman, is that long ago two of Triton's "
#          'daughters set out on a journey through the depths of the oceans and '
#          'seas. One of them decided to stay on the coast of Denmark and can be '
#          'seen sitting at the entrance to the port of Copenhagen. The second '
#          'mermaid reached the mouth of the Vistula River and plunged into its '
#          'waters. She stopped to rest on a sandy beach by the village of '
#          'Warszowa, where fishermen came to admire her beauty and listen to '
#          'her beautiful voice. A greedy merchant also heard her songs; he '
#          'followed the fishermen and captured the mermaid.'}
